# %%
import os
import json
import datetime
import plotly.express as px
import pandas as pd

# %%
path = 'data/instagram/'
bgeorgakas_path = path + 'instagram-bgeorgakas-2024-04-11-9ywghq7K/your_instagram_activity/'
about404_path = path + 'instagram-4b0ut404-2024-04-12-xkfnNfXv/your_instagram_activity'

# %%
def get_actions(path: str, reel_comments = True) -> list:
    with open(path + '/content/posts_1.json', 'r') as file:
        data = json.load(file)

    post_timestamps = []
    for chunk in data:
        for post in chunk['media']:
            post_timestamps.append(datetime.datetime.fromtimestamp(post['creation_timestamp'])) 

    with open(path + '/content/stories.json', 'r') as file:
        data = json.load(file)

    stories_timestamps = []
    for story in data['ig_stories']:
        stories_timestamps.append(datetime.datetime.fromtimestamp(story['creation_timestamp']))
    
    with open(path + '/comments/post_comments_1.json', 'r') as file:
        data = json.load(file)

    post_comments_timestamps = []
    for comment in data:
        post_comments_timestamps.append(
            datetime.datetime.fromtimestamp(
                comment['string_map_data']['Time']['timestamp']
            )
        )

    reels_comments_timestamps = []
    if reel_comments:
        with open(path + '/comments/reels_comments.json', 'r') as file:
            data = json.load(file)

        
        for comment in data['comments_reels_comments']:
            reels_comments_timestamps.append(
                datetime.datetime.fromtimestamp(
                    comment['string_map_data']['Time']['timestamp']
                )
            )

    return post_timestamps + stories_timestamps + post_comments_timestamps + reels_comments_timestamps

# %%
bgeorgakas_actions = get_actions(bgeorgakas_path)
about404_actions = get_actions(about404_path, reel_comments = False)

# %%
actions = bgeorgakas_actions + about404_actions
actions_df = pd.DataFrame(data = actions, columns = ['date_time'])
actions_df = actions_df.assign(date = actions_df.date_time.dt.date)

# %%
actions_df.sort_values(by = 'date_time').to_csv('instagram_actions.csv')

# %% [markdown]
# Posts

# %%
with open(path + '/content/posts_1.json', 'r') as file:
    data = json.load(file)

post_timestamps = []
for chunk in data:
    for post in chunk['media']:
        post_timestamps.append(datetime.datetime.fromtimestamp(post['creation_timestamp']))

# %%
post_timestamps
# Out:
# [datetime.datetime(2024, 4, 2, 16, 34, 33),
#  datetime.datetime(2024, 4, 2, 16, 34, 33),
#  datetime.datetime(2024, 4, 2, 16, 34, 33),
#  datetime.datetime(2024, 4, 2, 16, 34, 33),
#  datetime.datetime(2024, 4, 2, 16, 34, 33),
#  datetime.datetime(2024, 4, 2, 16, 34, 33),
#  datetime.datetime(2024, 4, 2, 16, 34, 33),
#  datetime.datetime(2024, 3, 7, 9, 36, 24)]

# %% [markdown]
# Stories

# %%
with open(path + '/content/stories.json', 'r') as file:
    data = json.load(file)

stories_timestamps = []
for story in data['ig_stories']:
    stories_timestamps.append(datetime.datetime.fromtimestamp(story['creation_timestamp']))

# %%
stories_timestamps
# Out:
# [datetime.datetime(2024, 4, 6, 14, 17, 59),
#  datetime.datetime(2024, 4, 6, 11, 34, 52),
#  datetime.datetime(2024, 4, 3, 17, 15, 49),
#  datetime.datetime(2024, 4, 3, 10, 57, 36),
#  datetime.datetime(2024, 4, 2, 8, 26, 3),
#  datetime.datetime(2024, 3, 25, 12, 46, 46),
#  datetime.datetime(2024, 3, 18, 15, 24, 48),
#  datetime.datetime(2024, 3, 13, 14, 14, 34),
#  datetime.datetime(2024, 3, 13, 14, 11, 39),
#  datetime.datetime(2024, 3, 11, 13, 21, 20),
#  datetime.datetime(2024, 3, 11, 13, 17),
#  datetime.datetime(2024, 3, 7, 9, 37, 50),
#  datetime.datetime(2024, 3, 7, 9, 37, 13),
#  datetime.datetime(2023, 8, 27, 18, 49, 4),
#  datetime.datetime(2023, 8, 23, 6, 53, 30),
#  datetime.datetime(2023, 8, 23, 6, 53, 10),
#  datetime.datetime(2023, 8, 10, 20, 8, 57),
#  datetime.datetime(2023, 7, 14, 5, 11, 57),
#  datetime.datetime(2023, 5, 27, 5, 41, 23),
#  datetime.datetime(2023, 5, 25, 23, 28, 16),
#  datetime.datetime(2023, 5, 7, 2, 45, 35),
#  datetime.datetime(2023, 4, 24, 3, 48, 23),
#  datetime.datetime(2023, 4, 16, 22, 55, 33)]

# %% [markdown]
# post comments

# %%
with open(path + '/comments/post_comments_1.json', 'r') as file:
    data = json.load(file)

post_comments_timestamps = []
for comment in data:
    post_comments_timestamps.append(
        datetime.datetime.fromtimestamp(
            comment['string_map_data']['Time']['timestamp']
        )
    )

# %%
post_comments_timestamps
# Out:
# [datetime.datetime(2024, 4, 10, 12, 10, 27),
#  datetime.datetime(2024, 4, 3, 21, 38, 45),
#  datetime.datetime(2024, 4, 3, 21, 38, 24),
#  datetime.datetime(2024, 4, 3, 12, 22, 57),
#  datetime.datetime(2024, 4, 2, 21, 55, 28),
#  datetime.datetime(2024, 4, 2, 17, 31, 24),
#  datetime.datetime(2024, 4, 2, 17, 29, 32),
#  datetime.datetime(2024, 4, 2, 17, 9, 25),
#  datetime.datetime(2024, 4, 2, 16, 42, 26),
#  datetime.datetime(2023, 9, 7, 1, 42, 22),
#  datetime.datetime(2023, 7, 29, 7, 38, 14),
#  datetime.datetime(2023, 4, 28, 22, 54, 16),
#  datetime.datetime(2023, 2, 13, 1, 47, 55),
#  datetime.datetime(2023, 1, 24, 23, 39, 6),
#  datetime.datetime(2022, 12, 22, 2, 39, 11),
#  datetime.datetime(2022, 12, 15, 13, 55, 21),
#  datetime.datetime(2022, 12, 8, 17, 40, 42),
#  datetime.datetime(2022, 12, 6, 19, 43, 53),
#  datetime.datetime(2022, 10, 18, 10, 7, 50),
#  datetime.datetime(2022, 8, 31, 23, 35, 34),
#  datetime.datetime(2022, 8, 22, 2, 26, 7),
#  datetime.datetime(2022, 5, 7, 15, 14, 2),
#  datetime.datetime(2022, 5, 2, 22, 5, 48),
#  datetime.datetime(2022, 4, 10, 19, 57, 54),
#  datetime.datetime(2022, 4, 5, 9, 30, 33),
#  datetime.datetime(2022, 3, 24, 22, 25, 50),
#  datetime.datetime(2022, 3, 24, 21, 55, 12),
#  datetime.datetime(2022, 3, 15, 15, 48, 21),
#  datetime.datetime(2022, 3, 15, 15, 22, 55),
#  datetime.datetime(2022, 3, 15, 15, 22, 12),
#  datetime.datetime(2021, 12, 20, 17, 47, 9),
#  datetime.datetime(2021, 12, 7, 15, 41, 32),
#  datetime.datetime(2021, 11, 28, 13, 52, 10),
#  datetime.datetime(2021, 11, 3, 19, 6, 46),
#  datetime.datetime(2021, 7, 31, 9, 23, 23),
#  datetime.datetime(2021, 7, 30, 21, 28, 7),
#  datetime.datetime(2021, 7, 24, 19, 51, 35),
#  datetime.datetime(2021, 7, 19, 16, 43, 44),
#  datetime.datetime(2021, 7, 11, 13, 1, 34),
#  datetime.datetime(2021, 7, 2, 19, 5, 6),
#  datetime.datetime(2021, 6, 5, 11, 7, 18),
#  datetime.datetime(2021, 5, 24, 17, 59, 46),
#  datetime.datetime(2021, 4, 18, 18, 39, 41),
#  datetime.datetime(2021, 3, 12, 6, 59, 25),
#  datetime.datetime(2021, 2, 23, 17, 39, 59),
#  datetime.datetime(2021, 2, 17, 9, 41, 55),
#  datetime.datetime(2021, 1, 12, 15, 35, 27),
#  datetime.datetime(2021, 1, 10, 13, 48, 44),
#  datetime.datetime(2020, 12, 18, 22, 41, 47),
#  datetime.datetime(2020, 12, 18, 22, 40, 29),
#  datetime.datetime(2020, 12, 18, 21, 48, 45),
#  datetime.datetime(2020, 10, 23, 21, 7, 2),
#  datetime.datetime(2020, 8, 30, 12, 55, 46),
#  datetime.datetime(2020, 8, 5, 21, 13, 10),
#  datetime.datetime(2020, 7, 15, 19, 53, 51),
#  datetime.datetime(2020, 6, 20, 17, 15, 2),
#  datetime.datetime(2020, 6, 15, 8, 32, 29),
#  datetime.datetime(2020, 6, 8, 23, 2, 18),
#  datetime.datetime(2020, 4, 22, 9, 19, 48),
#  datetime.datetime(2020, 4, 8, 18, 40, 6),
#  datetime.datetime(2020, 4, 4, 20, 57),
#  datetime.datetime(2020, 1, 24, 20, 33, 3),
#  datetime.datetime(2020, 1, 18, 18, 0, 24),
#  datetime.datetime(2020, 1, 18, 15, 39, 55),
#  datetime.datetime(2020, 1, 17, 21, 18, 58),
#  datetime.datetime(2020, 1, 17, 21, 17, 8),
#  datetime.datetime(2020, 1, 11, 14, 29, 26),
#  datetime.datetime(2019, 12, 28, 15, 0, 15),
#  datetime.datetime(2019, 12, 23, 15, 22, 47),
#  datetime.datetime(2019, 10, 19, 21, 28, 14),
#  datetime.datetime(2019, 10, 19, 13, 5, 46),
#  datetime.datetime(2019, 10, 14, 16, 9, 15),
#  datetime.datetime(2019, 9, 29, 21, 52, 32),
#  datetime.datetime(2019, 6, 9, 14, 20, 13),
#  datetime.datetime(2019, 2, 26, 22, 51, 56),
#  datetime.datetime(2019, 2, 26, 22, 9, 43),
#  datetime.datetime(2019, 2, 24, 17, 6, 59),
#  datetime.datetime(2019, 2, 20, 19, 29, 43),
#  datetime.datetime(2018, 11, 14, 15, 11, 23),
#  datetime.datetime(2018, 8, 22, 17, 54, 1),
#  datetime.datetime(2018, 8, 22, 17, 53, 41),
#  datetime.datetime(2018, 7, 11, 10, 11, 54),
#  datetime.datetime(2018, 7, 9, 21, 5, 4),
#  datetime.datetime(2018, 7, 5, 23, 18, 4),
#  datetime.datetime(2018, 7, 5, 23, 13, 33),
#  datetime.datetime(2018, 7, 5, 9, 35, 30),
#  datetime.datetime(2018, 7, 5, 0, 18, 36),
#  datetime.datetime(2018, 7, 5, 0, 6, 46),
#  datetime.datetime(2018, 7, 2, 14, 53, 25),
#  datetime.datetime(2018, 6, 26, 16, 47, 27),
#  datetime.datetime(2018, 2, 7, 22, 23, 42),
#  datetime.datetime(2018, 2, 7, 22, 23, 38),
#  datetime.datetime(2018, 2, 7, 22, 23, 35),
#  datetime.datetime(2018, 2, 7, 22, 23, 32),
#  datetime.datetime(2018, 2, 7, 22, 23, 28),
#  datetime.datetime(2018, 1, 27, 12, 20, 12),
#  datetime.datetime(2018, 1, 26, 21, 18, 24),
#  datetime.datetime(2018, 1, 4, 0, 5, 44),
#  datetime.datetime(2017, 12, 29, 17, 2, 38),
#  datetime.datetime(2017, 12, 21, 10, 26, 49),
#  datetime.datetime(2017, 11, 12, 9, 12, 51),
#  datetime.datetime(2017, 10, 9, 21, 27, 25),
#  datetime.datetime(2017, 9, 22, 15, 37, 4),
#  datetime.datetime(2017, 7, 25, 2, 44, 57),
#  datetime.datetime(2017, 7, 21, 3, 58, 57),
#  datetime.datetime(2017, 6, 8, 21, 38, 55),
#  datetime.datetime(2017, 3, 11, 22, 51, 45),
#  datetime.datetime(2017, 3, 11, 22, 27, 31),
#  datetime.datetime(2017, 2, 20, 17, 6, 50),
#  datetime.datetime(2017, 1, 28, 20, 29, 57),
#  datetime.datetime(2017, 1, 25, 16, 21, 44),
#  datetime.datetime(2017, 1, 20, 10, 8, 48),
#  datetime.datetime(2016, 12, 29, 8, 29, 29),
#  datetime.datetime(2016, 12, 29, 8, 29, 20),
#  datetime.datetime(2016, 12, 28, 20, 9, 57),
#  datetime.datetime(2016, 12, 28, 20, 9, 40),
#  datetime.datetime(2016, 12, 27, 14, 7, 57),
#  datetime.datetime(2016, 12, 24, 19, 14, 38),
#  datetime.datetime(2016, 12, 23, 23, 57, 7),
#  datetime.datetime(2016, 7, 4, 20, 1, 57),
#  datetime.datetime(2016, 6, 1, 8, 10, 1),
#  datetime.datetime(2016, 6, 1, 8, 9, 52),
#  datetime.datetime(2016, 5, 14, 9, 2, 1),
#  datetime.datetime(2016, 4, 15, 20, 44, 43),
#  datetime.datetime(2016, 4, 11, 18, 34, 19),
#  datetime.datetime(2016, 4, 8, 18, 58, 1),
#  datetime.datetime(2016, 3, 30, 7, 13, 51),
#  datetime.datetime(2016, 3, 24, 17, 17, 3),
#  datetime.datetime(2016, 3, 20, 10, 43, 58),
#  datetime.datetime(2016, 3, 20, 10, 30, 42),
#  datetime.datetime(2016, 3, 14, 19, 39, 34),
#  datetime.datetime(2016, 3, 14, 19, 38, 46),
#  datetime.datetime(2016, 3, 14, 19, 36, 55),
#  datetime.datetime(2016, 3, 14, 19, 34, 35),
#  datetime.datetime(2016, 3, 11, 23, 56, 54),
#  datetime.datetime(2016, 3, 11, 15, 53, 31),
#  datetime.datetime(2016, 3, 8, 8, 29, 15),
#  datetime.datetime(2016, 3, 8, 8, 29, 6),
#  datetime.datetime(2016, 3, 6, 18, 19, 48),
#  datetime.datetime(2016, 3, 2, 21, 39, 6),
#  datetime.datetime(2016, 3, 2, 21, 38, 52),
#  datetime.datetime(2016, 3, 2, 16, 23, 18),
#  datetime.datetime(2016, 2, 21, 15, 16, 16),
#  datetime.datetime(2016, 2, 15, 9, 59, 53),
#  datetime.datetime(2016, 2, 14, 8, 50, 44),
#  datetime.datetime(2016, 2, 13, 15, 14, 36),
#  datetime.datetime(2016, 2, 12, 18, 3, 50),
#  datetime.datetime(2016, 2, 8, 21, 45, 54),
#  datetime.datetime(2016, 2, 8, 21, 19, 42),
#  datetime.datetime(2016, 2, 4, 16, 48, 14),
#  datetime.datetime(2016, 2, 1, 17, 32, 2),
#  datetime.datetime(2016, 1, 30, 21, 19, 56),
#  datetime.datetime(2016, 1, 30, 21, 19, 35),
#  datetime.datetime(2016, 1, 30, 19, 1, 54),
#  datetime.datetime(2016, 1, 26, 23, 11, 44),
#  datetime.datetime(2016, 1, 26, 18, 26, 53),
#  datetime.datetime(2016, 1, 26, 18, 20, 44),
#  datetime.datetime(2016, 1, 26, 16, 6, 35),
#  datetime.datetime(2016, 1, 21, 19, 46, 37),
#  datetime.datetime(2016, 1, 16, 20, 30, 8),
#  datetime.datetime(2016, 1, 14, 23, 13, 47),
#  datetime.datetime(2016, 1, 12, 18, 25, 25),
#  datetime.datetime(2016, 1, 11, 21, 28, 30),
#  datetime.datetime(2016, 1, 10, 16, 58, 52),
#  datetime.datetime(2016, 1, 10, 8, 25, 58),
#  datetime.datetime(2016, 1, 9, 18, 20, 40),
#  datetime.datetime(2016, 1, 8, 19, 47, 15),
#  datetime.datetime(2016, 1, 4, 10, 11, 38),
#  datetime.datetime(2016, 1, 1, 17, 47, 52),
#  datetime.datetime(2016, 1, 1, 17, 47, 19),
#  datetime.datetime(2016, 1, 1, 16, 27, 52),
#  datetime.datetime(2016, 1, 1, 16, 26, 36),
#  datetime.datetime(1970, 1, 1, 10, 0),
#  datetime.datetime(1970, 1, 1, 10, 0),
#  datetime.datetime(1970, 1, 1, 10, 0),
#  datetime.datetime(1970, 1, 1, 10, 0),
#  datetime.datetime(1970, 1, 1, 10, 0),
#  datetime.datetime(1970, 1, 1, 10, 0),
#  datetime.datetime(1970, 1, 1, 10, 0),
#  datetime.datetime(1970, 1, 1, 10, 0),
#  datetime.datetime(1970, 1, 1, 10, 0),
#  datetime.datetime(2015, 12, 28, 21, 14, 45),
#  datetime.datetime(2015, 12, 25, 21, 0, 55),
#  datetime.datetime(2015, 12, 25, 9, 56, 5),
#  datetime.datetime(2015, 12, 25, 9, 55, 58),
#  datetime.datetime(2015, 12, 25, 9, 55, 52),
#  datetime.datetime(2015, 12, 24, 22, 20, 57),
#  datetime.datetime(2015, 12, 21, 9, 1, 7),
#  datetime.datetime(2015, 12, 21, 8, 52, 24),
#  datetime.datetime(2015, 12, 18, 20, 6, 13),
#  datetime.datetime(2015, 12, 18, 20, 3, 58),
#  datetime.datetime(2015, 12, 18, 20, 3, 47),
#  datetime.datetime(2015, 12, 13, 0, 53, 48),
#  datetime.datetime(2015, 12, 9, 21, 44, 29),
#  datetime.datetime(2015, 12, 3, 8, 6, 21),
#  datetime.datetime(2015, 12, 2, 19, 52, 15),
#  datetime.datetime(2015, 12, 2, 17, 55, 50),
#  datetime.datetime(2015, 11, 26, 21, 29, 54),
#  datetime.datetime(2015, 11, 25, 21, 14, 56),
#  datetime.datetime(2015, 11, 20, 22, 24, 25),
#  datetime.datetime(2015, 11, 15, 12, 19, 36),
#  datetime.datetime(2015, 11, 13, 19, 44, 33),
#  datetime.datetime(2015, 11, 2, 13, 52, 4),
#  datetime.datetime(2015, 11, 2, 10, 20, 7),
#  datetime.datetime(2015, 10, 28, 7, 51, 32),
#  datetime.datetime(2015, 10, 24, 13, 9, 50),
#  datetime.datetime(2015, 10, 2, 13, 29, 24),
#  datetime.datetime(2015, 10, 2, 7, 54, 11),
#  datetime.datetime(2015, 9, 28, 22, 36, 40),
#  datetime.datetime(2015, 9, 28, 20, 25, 58),
#  datetime.datetime(2015, 9, 24, 21, 9, 30),
#  datetime.datetime(2015, 9, 24, 15, 19, 10),
#  datetime.datetime(2015, 9, 21, 11, 25, 18),
#  datetime.datetime(2015, 9, 20, 9, 40, 34),
#  datetime.datetime(2015, 9, 12, 8, 20, 28),
#  datetime.datetime(2015, 9, 11, 22, 32, 37),
#  datetime.datetime(2015, 9, 11, 22, 10, 27),
#  datetime.datetime(2015, 9, 11, 22, 7, 48),
#  datetime.datetime(2015, 9, 8, 17, 51, 47),
#  datetime.datetime(2015, 9, 5, 11, 2, 31),
#  datetime.datetime(2015, 9, 5, 11, 2, 21),
#  datetime.datetime(2015, 9, 5, 8, 43, 25),
#  datetime.datetime(2015, 9, 1, 16, 47, 45),
#  datetime.datetime(2015, 8, 31, 19, 56, 12),
#  datetime.datetime(2015, 8, 30, 17, 42, 19),
#  datetime.datetime(2015, 8, 24, 15, 45, 8),
#  datetime.datetime(2015, 8, 22, 20, 27, 47),
#  datetime.datetime(2015, 8, 21, 17, 0, 38),
#  datetime.datetime(2015, 8, 21, 15, 54, 52),
#  datetime.datetime(2015, 8, 20, 20, 54, 3),
#  datetime.datetime(2015, 8, 20, 20, 44, 14),
#  datetime.datetime(2015, 8, 20, 20, 44, 4),
#  datetime.datetime(2015, 8, 13, 21, 48, 10),
#  datetime.datetime(2015, 8, 12, 8, 26, 39),
#  datetime.datetime(2015, 8, 3, 16, 45, 9),
#  datetime.datetime(2015, 7, 28, 15, 55, 10),
#  datetime.datetime(2015, 7, 8, 11, 13, 10),
#  datetime.datetime(2015, 6, 30, 13, 19, 43),
#  datetime.datetime(2015, 6, 27, 11, 26, 30),
#  datetime.datetime(2015, 6, 17, 15, 43, 1),
#  datetime.datetime(2015, 6, 16, 18, 50, 58),
#  datetime.datetime(2015, 6, 12, 17, 17, 16),
#  datetime.datetime(2015, 6, 12, 17, 2, 53),
#  datetime.datetime(2015, 6, 6, 20, 15, 40),
#  datetime.datetime(2015, 6, 6, 15, 43, 15),
#  datetime.datetime(2015, 6, 6, 13, 41, 2),
#  datetime.datetime(2015, 6, 6, 13, 40, 50),
#  datetime.datetime(2015, 6, 6, 13, 18, 57),
#  datetime.datetime(2015, 6, 6, 13, 14, 59),
#  datetime.datetime(2015, 6, 2, 17, 39, 1),
#  datetime.datetime(2015, 6, 2, 17, 33, 39),
#  datetime.datetime(2015, 6, 2, 17, 33, 25),
#  datetime.datetime(2015, 5, 28, 20, 0, 40),
#  datetime.datetime(2015, 5, 28, 19, 9, 7),
#  datetime.datetime(2015, 5, 28, 17, 28, 5),
#  datetime.datetime(2015, 5, 17, 20, 14, 33),
#  datetime.datetime(2015, 5, 17, 19, 50, 49),
#  datetime.datetime(2015, 5, 17, 19, 50, 42),
#  datetime.datetime(2015, 5, 15, 21, 26, 51),
#  datetime.datetime(2015, 5, 15, 19, 53, 7),
#  datetime.datetime(2015, 5, 15, 14, 14, 42),
#  datetime.datetime(2015, 5, 14, 21, 27, 31),
#  datetime.datetime(2015, 5, 14, 21, 25, 35),
#  datetime.datetime(2015, 5, 13, 18, 0, 7),
#  datetime.datetime(2015, 5, 11, 20, 16, 39),
#  datetime.datetime(2015, 5, 10, 16, 57, 43),
#  datetime.datetime(2015, 5, 8, 8, 17, 19),
#  datetime.datetime(2015, 4, 29, 16, 1, 28),
#  datetime.datetime(2015, 4, 26, 8, 42, 41),
#  datetime.datetime(2015, 4, 20, 18, 39),
#  datetime.datetime(2015, 4, 19, 18, 30, 57),
#  datetime.datetime(2015, 4, 17, 15, 55, 52),
#  datetime.datetime(2015, 4, 17, 7, 59, 46),
#  datetime.datetime(2015, 4, 16, 20, 21, 4),
#  datetime.datetime(2015, 4, 12, 11, 49, 38),
#  datetime.datetime(2015, 4, 11, 13, 1, 29),
#  datetime.datetime(2015, 3, 21, 17, 43, 18),
#  datetime.datetime(2015, 2, 28, 8, 20, 38),
#  datetime.datetime(2015, 2, 28, 8, 19, 50),
#  datetime.datetime(2015, 2, 17, 19, 48, 20),
#  datetime.datetime(2015, 2, 16, 19, 51, 34),
#  datetime.datetime(2015, 1, 22, 12, 48, 32),
#  datetime.datetime(2015, 1, 14, 19, 33, 41),
#  datetime.datetime(2015, 1, 13, 21, 14, 6),
#  datetime.datetime(2015, 1, 12, 18, 59, 25),
#  datetime.datetime(2015, 1, 4, 12, 14, 27),
#  datetime.datetime(2014, 12, 18, 7, 50, 49),
#  datetime.datetime(2014, 12, 17, 19, 44, 57),
#  datetime.datetime(2014, 12, 6, 18, 41, 48),
#  datetime.datetime(2014, 12, 4, 17, 14, 46),
#  datetime.datetime(2014, 12, 3, 16, 9, 14),
#  datetime.datetime(2014, 12, 1, 16, 57, 22),
#  datetime.datetime(2014, 11, 29, 14, 44, 12),
#  datetime.datetime(2014, 11, 26, 21, 5, 41),
#  datetime.datetime(2014, 11, 26, 21, 5),
#  datetime.datetime(2014, 11, 17, 19, 22, 34),
#  datetime.datetime(2014, 11, 4, 17, 33, 43),
#  datetime.datetime(2014, 10, 7, 7, 24),
#  datetime.datetime(2014, 10, 4, 21, 29, 24),
#  datetime.datetime(2014, 9, 28, 7, 11, 50),
#  datetime.datetime(2014, 9, 21, 9, 30, 58),
#  datetime.datetime(2014, 9, 20, 14, 16, 49),
#  datetime.datetime(2014, 9, 20, 13, 1, 20),
#  datetime.datetime(2014, 9, 7, 11, 19, 28),
#  datetime.datetime(2014, 8, 24, 18, 59, 59),
#  datetime.datetime(2014, 8, 12, 17, 27, 30),
#  datetime.datetime(2014, 8, 10, 17, 48, 41),
#  datetime.datetime(2014, 8, 10, 17, 48, 20),
#  datetime.datetime(2014, 8, 10, 17, 47, 59),
#  datetime.datetime(2014, 8, 9, 22, 22, 20),
#  datetime.datetime(2014, 8, 9, 22, 21, 41),
#  datetime.datetime(2014, 8, 9, 11, 57, 36),
#  datetime.datetime(2014, 8, 4, 20, 50, 25),
#  datetime.datetime(2014, 7, 19, 21, 33, 46),
#  datetime.datetime(2014, 7, 19, 20, 17, 56),
#  datetime.datetime(2014, 7, 8, 16, 8, 10),
#  datetime.datetime(2014, 7, 2, 21, 40, 15),
#  datetime.datetime(2014, 6, 27, 21, 17, 52),
#  datetime.datetime(2014, 6, 25, 16, 34, 9),
#  datetime.datetime(2014, 6, 13, 21, 29, 46),
#  datetime.datetime(2014, 6, 13, 21, 24, 45),
#  datetime.datetime(2014, 6, 2, 18, 16, 10),
#  datetime.datetime(2014, 5, 28, 21, 25, 29),
#  datetime.datetime(2014, 5, 23, 15, 53, 50),
#  datetime.datetime(2014, 5, 23, 15, 53, 39),
#  datetime.datetime(2014, 5, 22, 19, 50, 13),
#  datetime.datetime(2014, 5, 22, 19, 46, 34),
#  datetime.datetime(2014, 5, 22, 17, 34, 50),
#  datetime.datetime(2014, 5, 2, 20, 4, 26),
#  datetime.datetime(2014, 5, 1, 19, 37, 50),
#  datetime.datetime(2014, 5, 1, 19, 37, 34),
#  datetime.datetime(2014, 4, 3, 21, 1, 59),
#  datetime.datetime(2014, 3, 26, 20, 49, 29),
#  datetime.datetime(2014, 3, 26, 20, 47, 6),
#  datetime.datetime(2014, 1, 20, 21, 51, 8),
#  datetime.datetime(2014, 1, 13, 23, 13, 32),
#  datetime.datetime(2013, 12, 18, 8, 23, 51),
#  datetime.datetime(2013, 11, 30, 14, 47, 58),
#  datetime.datetime(2013, 11, 28, 8, 37, 9),
#  datetime.datetime(2013, 11, 28, 8, 36, 52),
#  datetime.datetime(2013, 11, 25, 7, 40, 40),
#  datetime.datetime(2013, 11, 25, 7, 40, 27)]

# %% [markdown]
# reels comments

# %%
with open(path + '/comments/reels_comments.json', 'r') as file:
    data = json.load(file)

reels_comments_timestamps = []
for comment in data['comments_reels_comments']:
    reels_comments_timestamps.append(
        datetime.datetime.fromtimestamp(
            comment['string_map_data']['Time']['timestamp']
        )
    )

# %%
reels_comments_timestamps
# Out:
# [datetime.datetime(2024, 4, 11, 19, 43, 14),
#  datetime.datetime(2024, 4, 11, 19, 43, 8),
#  datetime.datetime(2024, 4, 11, 19, 42, 40),
#  datetime.datetime(2024, 4, 11, 19, 42, 22),
#  datetime.datetime(2024, 4, 11, 19, 42, 9)]

# %% [markdown]
# collated

# %%
actions_dates = post_timestamps + stories_timestamps + post_comments_timestamps + reels_comments_timestamps

actions_df = pd.DataFrame(data = actions_dates, columns = ['date_time'])
actions_df = actions_df.assign(
    date = actions_df.date_time.dt.date
)

# %%
actions_df.groupby('date').count()
# Out:
#             date_time
# date
# 1970-01-01          9
# 2013-11-25          2
# 2013-11-28          2
# 2013-11-30          1
# 2013-12-18          1
# ...               ...
# 2024-04-02         13
# 2024-04-03          5
# 2024-04-06          2
# 2024-04-10          1
# 2024-04-11          5
#
# [254 rows x 1 columns]

# %%
actions_df.date_time.dt.
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 373    11
# 374    11
# 375    11
# 376    11
# 377    11
# Name: date_time, Length: 378, dtype: int32
